# %%
# %pip install numpy matplotlib pandas seaborn scikit-learn

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: numpy in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (2.5.2)
# Requirement already satisfied: matplotlib in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (3.11.1)
# Requirement already satisfied: pandas in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (3.0.5)
# Requirement already satisfied: seaborn in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (1.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=9 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from scikit-learn) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Requirement already satisfied: six>=1.5 in /Users/mohammadhhasan/Downloads/.conda/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
X = np.linspace(0, 10, 2000)
Y = 5 * X + 10 + np.random.normal(5, 2, len(X))
plt.scatter(X, Y, s=1)
plt.grid()
plt.xlabel('Input Feature')
plt.ylabel('Output Value')
plt.title('Synthetic Data for Linear Regression')
# Out:
# Text(0.5, 1.0, 'Synthetic Data for Linear Regression')

# %%
X_augmented = np.column_stack((np.ones(X.shape[0]), X))
print("Shape of augmented X:", X_augmented.shape)
print("First 5 rows of augmented X:\n", X_augmented[:5])
# Out:
# Shape of augmented X: (2000, 2)
# First 5 rows of augmented X:
#  [[1.         0.        ]
#  [1.         0.0050025 ]
#  [1.         0.010005  ]
#  [1.         0.0150075 ]
#  [1.         0.02001001]]
